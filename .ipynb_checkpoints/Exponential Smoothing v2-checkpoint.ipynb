# %%
#Source: https://www.bounteous.com/insights/2020/09/15/forecasting-time-series-model-using-python-part-one/

import warnings
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import statsmodels.api as sm
import pickle
from datetime import datetime
from matplotlib import pyplot as plt
from matplotlib.dates import date2num
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
# %matplotlib inline
import json
plt.close("all")

euroData = pd.read_csv("data\euro_countries_padded.csv")
with open("data/iso_country_codes.json", "r") as read_file:
    countryCodes = json.load(read_file)

warnings.filterwarnings("ignore")
euroData
# Out:
#        Unnamed: 0 iso_code location        date     total_cases  \
# 0               0      ALB  Albania  2019-12-31      0.00000000
# 1               1      ALB  Albania  2020-01-01      0.00000000
# 2               2      ALB  Albania  2020-01-02      0.00000000
# 3               3      ALB  Albania  2020-01-03      0.00000000
# 4               4      ALB  Albania  2020-01-04      0.00000000
# ...           ...      ...      ...         ...             ...
# 10641       10641      UKR  Ukraine  2020-11-06 430467.00000000
# 10642       10642      UKR  Ukraine  2020-11-07 440188.00000000
# 10643       10643      UKR  Ukraine  2020-11-08 450934.00000000
# 10644       10644      UKR  Ukraine  2020-11-09 460331.00000000
# 10645       10645      UKR  Ukraine  2020-11-10 469018.00000000
#
#            new_cases  new_cases_smoothed        population      total_tests  \
# 0         0.00000000          0.00000000  2877800.00000000       0.00000000
# ...

# %%
#Creating Training sets

#For entire Europe:
def Europe_training_set(beg_date='2020-01-01', end_date=euroData["date"].iloc[-1]):
    df = euroData.groupby("date")["new_cases"].sum().reset_index(name = "new_cases")
    df['date'] = pd.to_datetime(df['date'])
    # Set the date as index 
    df = df.set_index('date')
    # Select the proper time period for weekly aggreagation
    df = df[beg_date:end_date]
    return df

#For Country
def Country_training_set(iso_code, beg_date='2020-01-01', end_date=euroData["date"].iloc[-1]):
    df = euroData[euroData.iso_code==iso_code].groupby("date")["new_cases"].sum().reset_index(name = "new_cases")
    df['date'] = pd.to_datetime(df['date'])
    # Set the date as index 
    df = df.set_index('date')
    # Select the proper time period for weekly aggreagation
    df = df[beg_date:end_date]
    return df

# %%
df_eu = Europe_training_set(end_date='2020-11-07')
df_nor = Country_training_set('NOR',end_date='2020-11-07')
df_swe = Country_training_set('SWE',end_date='2020-11-07')
df_ger = Country_training_set('DEU',end_date='2020-11-07')

# %%
df_nor['new_cases'].min()
# Out:
# 0.0

# %%
def Initial_plot(df, country_name ='Europe'):
    y = df['new_cases']
    fig, ax = plt.subplots(figsize=(20, 6))
    plt.title("Number of Daily New Cases of COVID-19 in "+country_name)
    ax.plot(y,marker='.', linestyle='-', linewidth=0.5, label='Daily')
    ax.plot(y.resample('W').mean(),marker='o', markersize=8, linestyle='-', label='Weakly Mean Resample')
    ax.set_ylabel('Daily New Cases of COVID-19 in '+country_name)
    ax.legend();

# %%
Initial_plot(df_eu)
Initial_plot(df_nor, country_name = 'Norway')
Initial_plot(df_swe, country_name = 'Sweden')
Initial_plot(df_ger, country_name = 'Germany')

# %%
# graphs to show seasonal_decompose
def seasonal_decompose (y, country_name ='Europe'):
    decomposition = sm.tsa.seasonal_decompose(y, model='additive',extrapolate_trend='freq')
    fig = decomposition.plot()
    fig.set_size_inches(14,14)
    fig.suptitle("Decomposition of the Time Series of COVID-19 Cases in " + country_name, fontsize=16)
    plt.show()

# %%
y_eu = df_eu['new_cases']
y_nor = df_nor['new_cases']
y_swe = df_swe['new_cases']
y_ger = df_ger['new_cases']

seasonal_decompose(y_eu)
seasonal_decompose(y_nor, country_name ='Norway')
seasonal_decompose(y_swe, country_name ='Sweden')
seasonal_decompose(y_ger, country_name ='Germany')

# %%
### plot for Rolling Statistic for testing Stationarity
def test_stationarity(timeseries, title):
    
    #Determing rolling statistics
    rolmean = pd.Series(timeseries).rolling(window=12).mean() 
    rolstd = pd.Series(timeseries).rolling(window=12).std()
    
    fig, ax = plt.subplots(figsize=(16, 4))
    ax.plot(timeseries, label= title)
    ax.plot(rolmean, label='rolling mean');
    ax.plot(rolstd, label='rolling std (x10)');
    ax.legend()

# %%
pd.options.display.float_format = '{:.8f}'.format
test_stationarity(y_eu,'raw data')

# %%
#The model is not compatible for negative trend values, so we have to start it at May 1st

y = y_eu['2020-05-01':]

y_to_train = y[:'2020-10-15'] # dataset to train
y_to_val = y # last X months for test  
predict_date = len(y) - len(y_to_train) #len(y[:'2020-09-16'])  the number of data points for the test set

# %%
def ses(y, y_to_train,y_to_test,smoothing_level,predict_date):
    y.plot(marker='o', color='black', legend=True, figsize=(14, 7))
    
    fit1 = SimpleExpSmoothing(y_to_train).fit(smoothing_level=smoothing_level,optimized=False)
    fcast1 = fit1.forecast(predict_date).rename(r'$\alpha={}$'.format(smoothing_level))
    # specific smoothing level
    fcast1.plot(marker='o', color='blue', legend=True)
    fit1.fittedvalues.plot(marker='o',  color='blue')
    mse1 = ((fcast1 - y_to_test) ** 2).mean()
    print('The Root Mean Squared Error of our SES forecasts with smoothing level of {} is {}'.format(smoothing_level,round(np.sqrt(mse1), 2)))
    
    ## auto optimization
    fit2 = SimpleExpSmoothing(y_to_train).fit()
    fcast2 = fit2.forecast(predict_date).rename(r'$\alpha=%s$'%fit2.model.params['smoothing_level'])
    # plot
    fcast2.plot(marker='o', color='green', legend=True)
    fit2.fittedvalues.plot(marker='o', color='green')
    
    mse2 = ((fcast2 - y_to_test) ** 2).mean()
    print('The Root Mean Squared Error of our forecasts with auto optimization is {}'.format(round(np.sqrt(mse2), 2)))
    
    plt.show()

# %%
#ses(y, y_to_train,y_to_val,0.8,predict_date)
#ses(y, y_to_train,y_to_val,0.5,predict_date)

# %%
def holt(y,y_to_train,y_to_test,smoothing_level,smoothing_slope, predict_date):
    y.plot(marker='o', color='black', legend=True, figsize=(14, 7))
    
    fit1 = Holt(y_to_train).fit(smoothing_level, smoothing_slope, optimized=False)
    fcast1 = fit1.forecast(predict_date).rename("Holt's linear trend")
    mse1 = ((fcast1 - y_to_test) ** 2).mean()
    print('The Root Mean Squared Error of Holt''s Linear trend {}'.format(round(np.sqrt(mse1), 2)))

    fit2 = Holt(y_to_train, exponential=True).fit(smoothing_level, smoothing_slope, optimized=False)
    fcast2 = fit2.forecast(predict_date).rename("Exponential trend")
    mse2 = ((fcast2 - y_to_test) ** 2).mean()
    print('The Root Mean Squared Error of Holt''s Exponential trend {}'.format(round(np.sqrt(mse2), 2)))
    
    fit1.fittedvalues.plot(marker="o", color='blue')
    fcast1.plot(color='blue', marker="o", legend=True)
    fit2.fittedvalues.plot(marker="o", color='red', legend=True)
    fcast2.plot(color='red', marker="o", legend=True)

    plt.show()

# %%
#holt(y, y_to_train,y_to_val,0.6,0.2,predict_date)

# %%
def holt_win_sea(y,y_to_train,y_to_test,seasonal_type,seasonal_period,predict_date, ):
    
    y.plot(marker='o', color='black', legend=True, figsize=(14, 7))
    #ax.set_ylim([0,y.max()*3])
    
    if seasonal_type == 'additive':
        fit1 = ExponentialSmoothing(y_to_train, seasonal_periods = seasonal_period, trend='add', seasonal='add').fit(optimized=True)
        fcast1 = fit1.forecast(predict_date).rename('Additive')
        mse1 = ((fcast1 - y_to_test) ** 2).mean()
        print('The Root Mean Squared Error of additive trend, additive seasonal of '+ 
              'period season_length={} is {}'.format(seasonal_period,round(np.sqrt(mse1), 2)))
        mae1 = abs(fcast1 - y_to_test).mean()
        print('The Mean Absolute Error of additive trend, additive seasonal of '+ 
              'period season_length={} is {}'.format(seasonal_period,round(mae1, 2)))
        
        fit2 = ExponentialSmoothing(y_to_train, seasonal_periods = seasonal_period, trend='add', seasonal='add', damped=True).fit(optimized=True)
        fcast2 = fit2.forecast(predict_date).rename('Additive+damped')
        mse2 = ((fcast2 - y_to_test) ** 2).mean()
        print('The Root Mean Squared Error of additive damped trend, additive seasonal of '+ 
              'period season_length={} is {}'.format(seasonal_period,round(np.sqrt(mse2), 2)))
        mae2 = abs(fcast2 - y_to_test).mean()
        print('The Mean Absolute Error of additive damped trend, additive seasonal of '+ 
              'period season_length={} is {}'.format(seasonal_period,round(mae2, 2)))
        
        fit1.fittedvalues.plot(style='--', color='red')
        fcast1.plot(style='--', marker='o', color='red', legend=True)
        fit2.fittedvalues.plot(style='--', color='green')
        fcast2.plot(style='--', marker='o', color='green', legend=True)
    
    elif seasonal_type == 'multiplicative':  
        fit3 = ExponentialSmoothing(y_to_train, seasonal_periods = seasonal_period, trend='add', seasonal='mul').fit(optimized=True)
        fcast3 = fit3.forecast(predict_date).rename('Multiplicative')
        mse3 = ((fcast3 - y_to_test) ** 2).mean()
        print('The Root Mean Squared Error of additive trend, multiplicative seasonal of '+ 
              'period season_length={} is {}'.format(seasonal_period,round(np.sqrt(mse3), 2)))
        mae3 = abs(fcast3 - y_to_test).mean()
        print('The Mean Absolute Error of additive trend, multiplicative seasonal of '+ 
              'period season_length={} is {}'.format(seasonal_period,round(mae3, 2)))
        
        fit4 = ExponentialSmoothing(y_to_train, seasonal_periods = seasonal_period, trend='add', seasonal='mul', damped=True).fit(optimized=True)
        fcast4 = fit4.forecast(predict_date).rename('Multiplicative+damped')
        mse4 = ((fcast4 - y_to_test) ** 2).mean()
        print('The Root Mean Squared Error of additive damped trend, multiplicative seasonal of '+ 
              'period season_length={}, is {}'.format(seasonal_period,round(np.sqrt(mse4), 2)))
        mae4 = abs(fcast4 - y_to_test).mean()
        print('The Mean Absolute Error of additive damped trend, multiplicative seasonal of '+ 
              'period season_length={} is {}'.format(seasonal_period,round(mae4, 2)))
        
        fit3.fittedvalues.plot(style='--', color='red')
        fcast3.plot(style='--', marker='o', color='red', legend=True)
        fit4.fittedvalues.plot(style='--', color='green')
        fcast4.plot(style='--', marker='o', color='green', legend=True)
        
    else:
        print('Wrong Seasonal Type. Please choose between additive and multiplicative')

    plt.show()

# %%
#holt_win_sea(y, y_to_train,y_to_val,'additive',7, predict_date)

# %%
#holt_win_sea(y, y_to_train,y_to_val,'multiplicative',7, predict_date)

# %%
#The model is not compatible for negative trend values, so we have to start it at May 1st

def Europe_stats(s_date='2020-03-01',train_e_date='2020-10-31', test_s_date = '2020-11-01', e_date='2020-11-07', 
                  smoothing_level=0.5, smoothing_slope=0.5):
    df = Europe_training_set(end_date=e_date)
    name = "Europe"
        
    y = df['new_cases'].rename('Actual Reported Data')
    y = y[s_date:]
    y_to_train = y[:train_e_date]
        
    # dataset to train
    y_to_test = y[test_s_date:] # last X months for test
    predict_date = len(y) - len(y_to_train) 
    
    #Holt
    holt_lin_fit = Holt(y_to_train).fit(optimized=True)
    holt_lin_forecast = holt_lin_fit.forecast(predict_date).rename("Holt's Linear Trend")
    mae_holt_lin = abs(holt_lin_forecast - y_to_test).mean()
    
    
    holt_exp_fit = Holt(y_to_train, exponential=True).fit(optimized=True)
    holt_exp_forecast = holt_exp_fit.forecast(predict_date).rename("Holt's Exponential Trend")
    mae_holt_exp = abs(holt_exp_forecast - y_to_test).mean()
    
    
    #Holt-Winters-Additive Seasonal
    holtw_ad_fit = ExponentialSmoothing(y_to_train, seasonal_periods=7, trend='add', seasonal='add').fit(optimized=True)
    holtw_ad_forecast = holtw_ad_fit.forecast(predict_date).rename("Holt-Winter's Additive")
    mae_holtw_ad = abs(holtw_ad_forecast - y_to_test).mean()
    
    
    holtw_ad_damp_fit = ExponentialSmoothing(y_to_train, seasonal_periods = 7, trend='add', seasonal='add', damped=True).fit(optimized=True)
    holtw_ad_damp_forecast = holtw_ad_damp_fit.forecast(predict_date).rename("Holt-Winter's Additive+Damped")
    mae_holtw_ad_damp = abs(holtw_ad_damp_forecast - y_to_test).mean()
    
    
    #Holt-Winters-Seasonal Multiplicative
    holtw_mul_fit = ExponentialSmoothing(y_to_train, seasonal_periods=7, trend='add', seasonal='mul').fit(optimized=True)
    holtw_mul_forecast = holtw_mul_fit.forecast(predict_date).rename("Holt-Winter's Multiplicative")
    mae_holtw_mul = abs(holtw_mul_forecast - y_to_test).mean()
    
    holtw_mul_damp_fit = ExponentialSmoothing(y_to_train, seasonal_periods=7, trend='add', seasonal='mul', damped=True).fit(optimized=True)
    holtw_mul_damp_forecast = holtw_mul_damp_fit.forecast(predict_date).rename("Holt-Winter's Multiplicative+Dampened")
    mae_holtw_mul_damp = abs(holtw_mul_damp_forecast - y_to_test).mean()
    
    params = ['smoothing_level', 'smoothing_trend', 'damping_trend', 'initial_level', 'initial_trend']
    results=pd.DataFrame(index=[r"$\alpha$",r"$\beta$",r"$\phi$",r"$l_0$","$b_0$","MAE"] ,columns=["Holt's Lin. Trend","Holt's Exp. Trend","H-W Add.","H-W Add. + Damp.","H-W Mult.","H-W Mult. + Damp."])
    results["Holt's Lin. Trend"] =         [format(holt_lin_fit.params[p],".2f") for p in params] + [format(mae_holt_lin, ".2f")]
    results["Holt's Exp. Trend"] =    [format(holt_exp_fit.params[p],".2f") for p in params] + [format(mae_holt_exp, ".2f")]
    results["H-W Add."] =       [format(holtw_ad_fit.params[p],".2f") for p in params] + [format(mae_holtw_ad, ".2f")]
    results["H-W Add. + Damp."] = [format(holtw_ad_damp_fit.params[p],".2f") for p in params] + [format(mae_holtw_ad_damp, ".2f")]
    results["H-W Mult."] =       [format(holtw_mul_fit.params[p],".2f") for p in params] + [format(mae_holtw_mul, ".2f")]
    results["H-W Mult. + Damp."] = [format(holtw_mul_damp_fit.params[p],".2f") for p in params] + [format(mae_holtw_mul_damp, ".2f")]
    display(results)
    
    #print(
        #f"{name :^110}",
        #f"\n{'The Mean Absolute Error of Holt''s Linear trend is: ':<100}{round(mae_holt_lin, 2):>10}",
        #f"\n{'The Mean Absolute Error of Holt''s Exponential trend is: ':<100}{round(mae_holt_exp, 2):>10}",
        #f"\n{'The Mean Absolute Error of Holt-Winter''s Additive Seasonal, Additive Trend is: ':<100}{round(mae_holtw_ad, 2):>10}",
        #f"\n{'The Mean Absolute Error of Holt-Winter''s Additive Seasonal, Additive Dampened Trend is: ':<100}{round(mae_holtw_ad_damp, 2):>10}",
        #f"\n{'The Mean Absolute Error of Holt-Winter''s Multiplicative Seasonal, Additive Trend is: ':<100}{round(mae_holtw_mul, 2):>10}",
        #f"\n{'The Mean Absolute Error of Holt-Winter''s Multiplicative Seasonal, Additive Dampened Trend is: ':<100}{round(mae_holtw_mul_damp, 2):>10}",    
    #)
    
    return y, holt_lin_fit, holt_lin_forecast, holt_exp_fit, holt_exp_forecast, holtw_ad_fit, holtw_ad_forecast,holtw_ad_damp_fit, holtw_ad_damp_forecast, holtw_mul_fit, holtw_mul_forecast, holtw_mul_damp_fit, holtw_mul_damp_forecast

# %%
#The model is not compatible for negative trend values, so we have to start it at May 1st

def Country_stats(iso_cd=None, s_date='2020-03-01',train_e_date='2020-10-31', test_s_date = '2020-11-01', e_date='2020-11-07', 
                  smoothing_level=0.5, smoothing_slope=0.5):
    if (iso_cd==None):
        df = Europe_training_set(end_date=e_date)
        name = "Europe"
    else:
        df = Country_training_set(iso_code=iso_cd, end_date=e_date)
        name = iso_cd
        
    y = df['new_cases'].rename('Actual Reported Data')
    y = y[s_date:]
    y_to_train = y[:train_e_date]
    
    # dataset to train
    y_to_test = y[test_s_date:] # last X months for test
    predict_date = len(y) - len(y_to_train) 
    
    #Holt
    holt_lin_fit = Holt(y_to_train).fit(optimized=True)
    holt_lin_forecast = holt_lin_fit.forecast(predict_date).rename("Holt's linear trend")
    mae_holt_lin = abs(holt_lin_forecast - y_to_test).mean()
    
    #Holt-Winters-Additive Seasonal
    holtw_ad_fit = ExponentialSmoothing(y_to_train, seasonal_periods=7, trend='add', seasonal='add').fit(optimized=True)
    holtw_ad_forecast = holtw_ad_fit.forecast(predict_date).rename('Holt-Winter''s Additive')
    mae_holtw_ad = abs(holtw_ad_forecast - y_to_test).mean()
    
    
    holtw_ad_damp_fit = ExponentialSmoothing(y_to_train, seasonal_periods = 7, trend='add', seasonal='add', damped=True).fit(optimized=True)
    holtw_ad_damp_forecast = holtw_ad_damp_fit.forecast(predict_date).rename('Holt-Winter''s Additive+Damped')
    mae_holtw_ad_damp = abs(holtw_ad_damp_forecast - y_to_test).mean()
     
    print(
        f"{name :^110}",
        f"\n{'The Mean Absolute Error of Holt''s Linear trend is: ':<100}{round(mae_holt_lin, 2):>10}",
        f"\n{'The Mean Absolute Error of Holt-Winter''s Additive Seasonal, Additive Trend is: ':<100}{round(mae_holtw_ad, 2):>10}",
        f"\n{'The Mean Absolute Error of Holt-Winter''s Additive Seasonal, Additive Dampened Trend is: ':<100}{round(mae_holtw_ad_damp, 2):>10}",
    )
    
    return y, holt_lin_fit, holt_lin_forecast, holtw_ad_fit, holtw_ad_forecast, holtw_ad_damp_fit, holtw_ad_damp_forecast

# %%
def plot_methods(iso_code=None, start_date='2020-10-10', end_date='2020-11-08', smoothing_level=0.5, smoothing_slope=0.5):
    if (iso_code==None):
        y, holt_lin_fit, holt_lin_forecast,\
        holt_exp_fit, holt_exp_forecast,\
        holtw_ad_fit, holtw_ad_forecast,\
        holtw_ad_damp_fit, holtw_ad_damp_forecast,\
        holtw_mul_fit, holtw_mul_forecast, \
        holtw_mul_damp_fit,holtw_mul_damp_forecast, results = Europe_stats(smoothing_level=smoothing_level, smoothing_slope=smoothing_slope)
        
        y.plot(marker='o', color='black', legend="Actual Number of Cases", figsize=(14, 7), xlim=(start_date,end_date))
        
        #holt_lin_fit.fittedvalues.plot(style='--', color='red', xlim=(start_date,end_date))
        holt_lin_forecast.plot(style='--', marker='o', color='red', legend=True, xlim=(start_date,end_date))
        
        #holt_exp_fit.fittedvalues.plot(style='--', color='blue', xlim=(start_date,end_date))
        holt_exp_forecast.plot(style='--', marker='o', color='blue', legend=True, xlim=(start_date,end_date))
        
        #holtw_ad_fit.fittedvalues.plot(style='--', color='green', xlim=(start_date,end_date))
        holtw_ad_forecast.plot(style='--', marker='o', color='green', legend=True, xlim=(start_date,end_date))
        
        #holtw_ad_damp_fit.fittedvalues.plot(style='--', color='purple', xlim=(start_date,end_date))
        holtw_ad_damp_forecast.plot(style='--', marker='o', color='purple', legend=True, xlim=(start_date,end_date))
        
        #holtw_mul_fit.fittedvalues.plot(style='--', color='orange', xlim=(start_date,end_date))
        holtw_mul_forecast.plot(style='--', marker='o', color='orange', legend=True, xlim=(start_date,end_date))
        
        #holtw_mul_damp_fit.fittedvalues.plot(style='--', color='pink', xlim=(start_date,end_date))
        holtw_mul_damp_forecast.plot(style='--', marker='o', color='pink', legend=True, xlim=(start_date,end_date))
        
        plt.title("Comparison of different forecasting methods - Europe")
        plt.ylim(0, None)
        plt.axvspan('2020-11-01', '2020-11-08',alpha=0.1, color='grey' )
        plt.ylabel("Daily new COVID-19 cases")
        plt.xlabel("Date")
        
        print(results)
        
        
    else:
        y, holt_lin_fit, holt_lin_forecast,\
        holtw_ad_fit, holtw_ad_forecast, \
        holtw_ad_damp_fit, holtw_ad_damp_forecast = Country_stats(iso_cd=iso_code, smoothing_level=smoothing_level, smoothing_slope=smoothing_slope)
        
                
        y.plot(marker='o', color='black', legend="Actual Number of Cases", figsize=(14, 7), xlim=(start_date,end_date))
        
        #holt_lin_fit.fittedvalues.plot(style='--', color='red', xlim=(start_date,end_date))
        holt_lin_forecast.plot(style='--', marker='o', color='red', legend=True, xlim=(start_date,end_date))
        
        #holtw_ad_fit.fittedvalues.plot(style='--', color='green', xlim=(start_date,end_date))
        holtw_ad_forecast.plot(style='--', marker='o', color='green', legend=True, xlim=(start_date,end_date))
        
        #holtw_ad_damp_fit.fittedvalues.plot(style='--', color='purple', xlim=(start_date,end_date))
        holtw_ad_damp_forecast.plot(style='--', marker='o', color='purple', legend=True, xlim=(start_date,end_date))
        
        plt.title("Comparison of different forecasting methods - "+iso_code)
        plt.ylim(0, None)
        plt.axvspan('2020-11-01', '2020-11-08',alpha=0.1, color='grey' )
        plt.ylabel("Daily new COVID-19 cases")
        plt.xlabel("Date")

# %%
#y, holt_lin_fit, holt_lin_forecast, holt_exp_fit, holt_exp_forecast, holtw_ad_fit, holtw_ad_forecast,holtw_ad_damp_fit, holtw_ad_damp_forecast, holtw_mul_fit, holtw_mul_forecast, holtw_mul_damp_fit, holtw_mul_damp_forecast = Europe_stats()
#hw_ad_eur = holtw_ad_forecast

#y, holt_lin_fit, holt_lin_forecast, holtw_ad_fit, holtw_ad_forecast, holtw_ad_damp_fit, holtw_ad_damp_forecast = Country_stats('NOR')
#hw_ad_nor = holtw_ad_forecast

#y, holt_lin_fit, holt_lin_forecast, holtw_ad_fit, holtw_ad_forecast, holtw_ad_damp_fit, holtw_ad_damp_forecast = Country_stats('DEU')
#hw_ad_deu = holtw_ad_forecast

#y, holt_lin_fit, holt_lin_forecast, holtw_ad_fit, holtw_ad_forecast, holtw_ad_damp_fit, holtw_ad_damp_forecast = Country_stats('ESP')
#hw_ad_esp = holtw_ad_forecast

# %%
#hw_ad_eur.to_pickle('hw_predictions/holt_winters_Europe.pkl')
#hw_ad_nor.to_pickle('hw_predictions/holt_winters_NOR.pkl')
#hw_ad_deu.to_pickle('hw_predictions/holt_winters_DEU.pkl')
#hw_ad_esp.to_pickle('hw_predictions/holt_winters_ESP.pkl')

Europe_stats()
# Out:
#          Holt's Lin. Trend  Holt's Exp. Trend       H-W Add.  \
# $\alpha$              0.24         0.24000000     0.29000000
# $\beta$               0.24         0.24000000     0.29000000
# $\phi$                 nan                nan            nan
# $l_0$               413.00       413.00000000 29056.83000000
# $b_0$               279.00         1.68000000   507.22000000
# MAE         38318.71000000     57436.78000000 23161.39000000
#
#           H-W Add. + Damp.      H-W Mult.  H-W Mult. + Damp.
# $\alpha$        0.29000000     0.25000000         0.25000000
# $\beta$         0.29000000     0.23000000         0.25000000
# $\phi$          0.99000000            nan         0.99000000
# $l_0$       29056.83000000 29056.83000000     29056.83000000
# $b_0$         507.22000000   507.22000000       507.22000000
# MAE         20156.53000000 23130.81000000     20504.99000000
# (date
#  2020-03-01      413.00000000
#  2020-03-02      692.00000000
#  2020-03-03      532.00000000
# ...

# %%
plot_methods()
# Out:
#                                                     Europe
# The Mean Absolute Error of Holts Linear trend is:                                                     38318.71
# The Mean Absolute Error of Holts Exponential trend is:                                                57436.78
# The Mean Absolute Error of Holt-Winters Additive Seasonal, Additive Trend is:                         23161.39
# The Mean Absolute Error of Holt-Winters Additive Seasonal, Additive Dampened Trend is:                20156.53
# The Mean Absolute Error of Holt-Winters Multiplicative Seasonal, Additive Trend is:                   23130.81
# The Mean Absolute Error of Holt-Winters Multiplicative Seasonal, Additive Dampened Trend is:          20504.99
#           Holt's Linear Trend  Holt's Exponential Trend  \
# $\alpha$           0.24071429                0.24071429
# $\beta$            0.24071429                0.24071429
# $\phi$                    nan                       nan
# ...

# %%
plot_methods('NOR')
# Out:
#                                                      NOR
# The Mean Absolute Error of Holts Linear trend is:                                                       251.24
# The Mean Absolute Error of Holt-Winters Additive Seasonal, Additive Trend is:                           205.54
# The Mean Absolute Error of Holt-Winters Additive Seasonal, Additive Dampened Trend is:                  226.52

# %%
plot_methods('ESP')
# Out:
#                                                      ESP
# The Mean Absolute Error of Holts Linear trend is:                                                     12921.66
# The Mean Absolute Error of Holt-Winters Additive Seasonal, Additive Trend is:                          3845.33
# The Mean Absolute Error of Holt-Winters Additive Seasonal, Additive Dampened Trend is:                 3656.58

# %%
plot_methods('DEU')
# Out:
#                                                      DEU
# The Mean Absolute Error of Holts Linear trend is:                                                      3456.73
# The Mean Absolute Error of Holt-Winters Additive Seasonal, Additive Trend is:                          2630.28
# The Mean Absolute Error of Holt-Winters Additive Seasonal, Additive Dampened Trend is:                 2467.81

# %%
hw_eur = pd.read_pickle('hw_predictions/holt_winters_Europe.pkl')
rf_eur = pd.read_pickle('rf_predictions/rf_europe.pkl')

# %%
pd.read_pickle('rf_predictions/rf_europe.pkl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\miniconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\miniconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
def plot_methods(iso_code=None, start_date='2020-10-17', end_date='2020-11-08', smoothing_level=0.5, smoothing_slope=0.5):
    if (iso_code==None):
        y, holt_lin_fit, holt_lin_forecast,\
        holt_exp_fit, holt_exp_forecast,\
        holtw_ad_fit, holtw_ad_forecast,\
        holtw_ad_damp_fit, holtw_ad_damp_forecast,\
        holtw_mul_fit, holtw_mul_forecast, \
        holtw_mul_damp_fit,holtw_mul_damp_forecast = Europe_stats(smoothing_level=smoothing_level, smoothing_slope=smoothing_slope)
        
        y.plot(marker='o', color='black', legend="Actual Number of Cases", figsize=(14, 7), xlim=(start_date,end_date))
        
        #holt_lin_fit.fittedvalues.plot(style='--', color='red', xlim=(start_date,end_date))
        holt_lin_forecast.plot(style='--', marker='o', color='red', legend=True, xlim=(start_date,end_date))
        
        #holt_exp_fit.fittedvalues.plot(style='--', color='blue', xlim=(start_date,end_date))
        holt_exp_forecast.plot(style='--', marker='o', color='blue', legend=True, xlim=(start_date,end_date))
        
        #holtw_ad_fit.fittedvalues.plot(style='--', color='green', xlim=(start_date,end_date))
        holtw_ad_forecast.plot(style='--', marker='o', color='green', legend=True, xlim=(start_date,end_date))
        
        #holtw_ad_damp_fit.fittedvalues.plot(style='--', color='purple', xlim=(start_date,end_date))
        holtw_ad_damp_forecast.plot(style='--', marker='o', color='purple', legend=True, xlim=(start_date,end_date))
        
        #holtw_mul_fit.fittedvalues.plot(style='--', color='orange', xlim=(start_date,end_date))
        holtw_mul_forecast.plot(style='--', marker='o', color='orange', legend=True, xlim=(start_date,end_date))
        
        #holtw_mul_damp_fit.fittedvalues.plot(style='--', color='pink', xlim=(start_date,end_date))
        holtw_mul_damp_forecast.plot(style='--', marker='o', color='pink', legend=True, xlim=(start_date,end_date))
        
        plt.title("Comparison of different forecasting methods - Europe")
        plt.ylim(0, None)
        plt.axvspan('2020-11-01', '2020-11-08',alpha=0.1, color='grey' )
        plt.ylabel("Daily new COVID-19 cases")
        plt.xlabel("Date")
        
        
    else:
        y, holt_lin_fit, holt_lin_forecast,\
        holtw_ad_fit, holtw_ad_forecast, \
        holtw_ad_damp_fit, holtw_ad_damp_forecast = Country_stats(iso_cd=iso_code, smoothing_level=smoothing_level, smoothing_slope=smoothing_slope)
        
                
        y.plot(marker='o', color='black', legend="Actual Number of Cases", figsize=(14, 7), xlim=(start_date,end_date))
        
        #holt_lin_fit.fittedvalues.plot(style='--', color='red', xlim=(start_date,end_date))
        holt_lin_forecast.plot(style='--', marker='o', color='red', legend=True, xlim=(start_date,end_date))
        
        #holtw_ad_fit.fittedvalues.plot(style='--', color='green', xlim=(start_date,end_date))
        holtw_ad_forecast.plot(style='--', marker='o', color='green', legend=True, xlim=(start_date,end_date))
        
        #holtw_ad_damp_fit.fittedvalues.plot(style='--', color='purple', xlim=(start_date,end_date))
        holtw_ad_damp_forecast.plot(style='--', marker='o', color='purple', legend=True, xlim=(start_date,end_date))
        
        plt.title("Comparison of different forecasting methods - "+iso_code)
        plt.ylim(0, None)
        plt.axvspan('2020-11-01', '2020-11-08',alpha=0.1, color='grey' )
        plt.ylabel("Daily new COVID-19 cases")
        plt.xlabel("Date")
